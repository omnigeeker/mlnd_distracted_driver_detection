# %% [markdown]
# ## View the train data

# %%
import os
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

dir = "/ext/Data/distracted_driver_detection/"

driver_imgs_list_csv = os.path.join(dir, "driver_imgs_list.csv")
df = pd.read_csv(driver_imgs_list_csv)
print("there are %d images"%len(df))
drivers = df["subject"].unique()
print("there are %d drivers "%len(drivers))
df1 = df[(df["subject"]==drivers[0]) & (df["classname"]=='c2')]

plt.figure(figsize=(15,25))

i = 0
for index, row in df1[:10].iterrows():
    path = os.path.join(dir, "train", row["classname"], row["img"])
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    i += 1
    plt.subplot(5,2,i)
    plt.imshow(img)
    plt.axis('off')
plt.show()
# Out:
# there are 22424 images
# there are 26 drivers

# %%
plt.figure(figsize=(15,25))
i = 0
for index, row in df1[-10:].iterrows():
    path = os.path.join(dir, "train", row["classname"], row["img"])
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    i += 1
    plt.subplot(5,2,i)
    plt.imshow(img)
    plt.axis('off')
plt.show()

# %%
# -*- coding: utf-8 -*-
"""
@author: Giba1
"""
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import sys
from skimage import io, transform
import matplotlib.animation as animation

train = pd.read_csv( dir + 'driver_imgs_list.csv')
train['id'] = range( train.shape[0] )
fig = plt.figure()
subj = np.unique( train['subject'])[0]

for subj in np.unique( train['subject'])[:2]:

    imagem = train[ train['subject']==subj ]
    imgs = []
    t = imagem.values[0]
    for t in imagem.values:
        img = cv2.imread(dir + '/train/'+t[1]+'/'+t[2],3)
        img = cv2.resize(img, (160, 120))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        imgs.append( img )
        
    ax = fig.add_subplot(111)
    ax.set_axis_off()
    fig.subplots_adjust(left=0, bottom=0, right=1, top=1,wspace=None, hspace=None)  # removes white border
    fname = 'MOVIE_subject_'+subj+'.gif'
    imgs = [ (ax.imshow(img), 
              ax.set_title(t[0]), 
              ax.annotate(n_img,(5,5))) for n_img, img in enumerate(imgs) ] 
    img_anim = animation.ArtistAnimation(fig, imgs, interval=125, repeat_delay=1000, blit=False)
    print('Writing:', fname)
    #img_anim.save(fname, writer='imagemagick', dpi=20)
    fig.clf()
print ('Now relax and watch some movies!!!')
# Out:
# Writing: MOVIE_subject_p002.gif
# Writing: MOVIE_subject_p012.gif
# Now relax and watch some movies!!!
